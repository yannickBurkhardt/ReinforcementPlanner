# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
scores = np.load('experiments/01_ppo/scores_crawler.npz')
print(scores.files)
scores_avg = []
s = -5
for score in scores['arr_0']:
    s = s*0.9+score*0.1
    scores_avg.append(s)
# Out:
# ['arr_0']

# %%
plt.plot(scores['arr_0'])
plt.plot(scores_avg)
plt.show()
